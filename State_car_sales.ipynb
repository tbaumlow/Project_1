# %%
# Create Dataframe from the car sales price data

import pandas as pd
car_df = pd.read_csv('/car_prices.csv')
car_df
# Out:
#        year      make                model        trim   body transmission  \
# 0      2015       Kia              Sorento          LX    SUV    automatic
# 1      2015       Kia              Sorento          LX    SUV    automatic
# 2      2014       BMW             3 Series  328i SULEV  Sedan    automatic
# 3      2015     Volvo                  S60          T5  Sedan    automatic
# 4      2014       BMW  6 Series Gran Coupe        650i  Sedan    automatic
# ...     ...       ...                  ...         ...    ...          ...
# 33437  2013  Infiniti                    M         M37  Sedan    automatic
# 33438  2013       Kia               Optima          LX  Sedan    automatic
# 33439  2013      Jeep              Patriot       Sport    SUV    automatic
# 33440  2013       Kia                Forte          EX  Sedan    automatic
# 33441  2013    Jaguar                   XF        Base  Sedan    automatic
#
# ...

# %%
# Describe the numeric columns in the data set
car_df.describe()
# Out:
#                year     condition       odometer            mmr   sellingprice
# count  33442.000000  23431.000000   33378.000000   33442.000000   33441.000000
# mean    2008.056247     28.659340   88667.867098   11151.622660   10764.667594
# std        4.520523     13.845484   60701.041824    9794.319094    9771.633531
# min     1986.000000      1.000000       1.000000      25.000000       1.000000
# 25%     2005.000000     19.000000   36836.000000    3800.000000    3400.000000
# 50%     2008.000000     31.000000   84457.500000    8950.000000    8500.000000
# 75%     2012.000000     39.000000  127712.750000   15900.000000   15500.000000
# max     2015.000000     49.000000  999999.000000  157000.000000  154000.000000

# %%
# Count the unique vehicle makes

car_df['state'].nunique()
# Out:
# 36

# %%
# Top 10 States by Cars sold

import matplotlib.pyplot as plt

# Create a bar chart of the top 10 states by count
car_df['state'].value_counts().head(10).plot(kind='bar')

# Add a title and labels
plt.title('Top 10 States by Car Sales')
plt.xlabel('State')
plt.ylabel('Count')

# Rotate the x-axis labels for readability
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %%
# prompt: show the top 10 states by average sellingprice

# Calculate the average selling price for each state
average_selling_price_by_state = car_df.groupby('state')['sellingprice'].mean()

# Sort the states by average selling price in descending order
top_10_states_by_avg_selling_price = average_selling_price_by_state.sort_values(ascending=False).head(10)

# Create a bar chart of the top 10 states by average selling price
top_10_states_by_avg_selling_price.plot(kind='bar')

# Add a title and labels
plt.title('Top 10 States by Average Selling Price')
plt.xlabel('State')
plt.ylabel('Average Selling Price')

# Rotate the x-axis labels for readability
plt.xticks(rotation=45)

# Display the plot
plt.show()
